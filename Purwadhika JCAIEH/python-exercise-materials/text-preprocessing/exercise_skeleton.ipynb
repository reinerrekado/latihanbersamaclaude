# %% [markdown]
# # EXERCISE SKELETON - Text Preprocessing
#
# 6 exercises using `sample_reviews.csv`, which sits next to this
# notebook (read it with a relative path like
# `pd.read_csv("sample_reviews.csv")`). It's a small, made-up dataset
# of messy product/movie reviews - HTML tags, URLs, inconsistent
# casing, extra whitespace, and repeated punctuation, on purpose.
#
# Each function's comment describes what it should do, but not exactly
# how - that's for you to work out using what you saw in the demo
# notebooks (`01` through `06`).
#
# Fill in each function, then run its cell to see the result.
#
# **Try to solve each one yourself before checking the answer key.**

# %%
import re
import pandas as pd
import nltk

nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('stopwords', quiet=True)

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()

df = pd.read_csv("sample_reviews.csv")
df.head()

# %% [markdown]
# ---
# ### Exercise 1: Clean the review text

# %%
# Remove HTML tags, URLs, and extra whitespace from `text`.
# Return the cleaned string (don't lowercase or remove punctuation yet -
# that's later exercises).
def clean_review(text):
    pass


clean_review(df.loc[3, 'review'])

# %% [markdown]
# ---
# ### Exercise 2: Normalize case

# %%
# Lowercase `text`.
def normalize_case(text):
    pass


normalize_case(df.loc[0, 'review'])

# %% [markdown]
# ---
# ### Exercise 3: Tokenize and remove stop words

# %%
# Tokenize `text` into words, then remove English stop words.
# Return the list of remaining tokens.
def tokenize_and_remove_stopwords(text):
    pass


tokenize_and_remove_stopwords("This movie was not good at all")

# %% [markdown]
# ---
# ### Exercise 4: Stem tokens

# %%
# Apply the Porter stemmer to every token in `tokens`.
# Return the list of stemmed tokens.
def stem_tokens(tokens):
    pass


stem_tokens(["running", "runners", "shoes"])

# %% [markdown]
# ---
# ### Exercise 5: Full pipeline

# %%
# Combine exercises 1-4 into a single pipeline:
# clean -> normalize case -> tokenize -> remove stop words -> stem.
# Return the result as a single space-joined string (not a list).
def preprocess_review(text):
    pass


df['processed'] = df['review'].apply(preprocess_review)
df[['review', 'processed']]

# %% [markdown]
# ---
# ### Exercise 6: Vocabulary size, before vs. after

# %%
# Compare the number of *unique* words across the whole `review` column
# before preprocessing (naive `.split()` on the raw text) against the
# number of unique words across the whole `processed` column. What
# happened to the vocabulary size, and why?
def compare_vocabulary_size(df):
    pass


compare_vocabulary_size(df)
