# %% [markdown]
# # EXERCISE SKELETON - Data Visualization
#
# 5 exercises using `Titanic-Dataset.csv`, which sits next to this
# notebook (read it with a relative path like
# `pd.read_csv("Titanic-Dataset.csv")`).
#
# Each function's comment describes what the chart should show and what
# question to answer - not which exact function calls to use. Work that
# out yourself from the demo notebooks (`01` through `07`) before
# checking the answer key.
#
# Fill in each function, then run its cell to see the plot and answer
# the question in the comment (as a print statement, a markdown note, or
# just to yourself).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Titanic-Dataset.csv")
df.head()

# %% [markdown]
# ---
# ### Exercise 1: Survivors vs. Non-Survivors

# %%
# Compare the number of passengers who survived against the number
# who didn't, using a bar plot. Which group is bigger?
def survivors_bar_plot(df):
    pass


survivors_bar_plot(df)

# %% [markdown]
# ---
# ### Exercise 2: Age Distribution

# %%
# Show the distribution of the Age column. Note that Age has some
# missing values - decide how you want to handle those before
# plotting. What shape does the distribution have, and where's it
# centered?
def age_histogram(df):
    pass


age_histogram(df)

# %% [markdown]
# ---
# ### Exercise 3: Fare by Survival

# %%
# Compare the distribution of Fare between passengers who survived
# and those who didn't. Which group paid a higher median fare? Does
# either group have obvious outliers?
def fare_boxplot_by_survival(df):
    pass


fare_boxplot_by_survival(df)

# %% [markdown]
# ---
# ### Exercise 4: Age vs. Fare

# %%
# Plot Age against Fare. Is there any visible relationship or
# pattern between the two?
def age_fare_scatter(df):
    pass


age_fare_scatter(df)

# %% [markdown]
# ---
# ### Exercise 5: Correlation Heatmap

# %%
# Compute the correlation matrix for the dataset's numerical columns
# (drop any ID-like column first - it isn't a meaningful variable),
# then visualize it as a heatmap. Which pair of variables, other than
# a variable paired with itself, has the strongest correlation?
def correlation_heatmap(df):
    pass


correlation_heatmap(df)
